# %% [markdown]
# # Strategy Optimization with Smoothing (the optimal frequency)

# %% [markdown]
# ---

# %% [markdown]
# # Getting started

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
# Version 3.0 (advanced Performance Optimization)

class ConBacktester():
    ''' Class for the vectorized backtesting of simple contrarian trading strategies.
    
    Attributes
    ============
    filepath: str
        local filepath of the dataset (csv-file)
    symbol: str
        ticker symbol (instrument) to be backtested
    start: str
        start date for data import
    end: str
        end date for data import
    tc: float
        proportional trading costs per trade
    
    
    Methods
    =======
    get_data:
        imports the data.
        
    test_strategy:
        prepares the data and backtests the trading strategy incl. reporting (wrapper).
        
    prepare_data:
        prepares the data for backtesting.
    
    run_backtest:
        runs the strategy backtest.
        
    plot_results:
        plots the cumulative performance of the trading strategy compared to buy-and-hold.
        
    optimize_strategy:
        backtests strategy for different parameter values incl. optimization and reporting (wrapper).
    
    find_best_strategy:
        finds the optimal strategy (global maximum) given the window parameter range.
        
    visualize_many:
        plots parameter values vs. performance. 
        
    print_performance:
        calculates and prints various performance metrics.
        
    '''    
    
    def __init__(self, filepath, symbol, start, end, tc):
        
        self.filepath = filepath
        self.symbol = symbol
        self.start = start
        self.end = end
        self.tc = tc
        self.results = None
        self.get_data()
        self.tp_year = (self.data.price.count() / ((self.data.index[-1] - self.data.index[0]).days / 365.25))
        
    def __repr__(self):
        return "ConBacktester(symbol = {}, start = {}, end = {})".format(self.symbol, self.start, self.end)
        
    def get_data(self):
        ''' Imports the data.
        '''
        raw = pd.read_csv(self.filepath, parse_dates = ["time"], index_col = "time")
        raw = raw[self.symbol].to_frame().fillna(method = "ffill") 
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw.price / raw.price.shift(1))
        self.data = raw
        
    def test_strategy(self, window = 1):
        '''
        Prepares the data and backtests the trading strategy incl. reporting (Wrapper).
         
        Parameters
        ============
        window: int
            time window (number of bars) to be considered for the strategy.
        '''
        self.window = window
                                
        self.prepare_data(window)
        self.run_backtest()
        
        data = self.results.copy()
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data
        
        self.print_performance()
    
    def prepare_data(self, window):
        ''' Prepares the Data for Backtesting.
        '''
        data = self.data.copy()
        data["roll_return"] = data["returns"].rolling(window).mean()
        data["position"] = -np.sign(data["roll_return"])
        self.results = data
    
    def run_backtest(self):
        ''' Runs the strategy backtest.
        '''
        
        data = self.results.copy()
        data["strategy"] = data["position"].shift(1) * data["returns"]
        data.dropna(inplace=True)
        
        # determine the number of trades in each bar
        data["trades"] = data.position.diff().fillna(0).abs()
        
        # subtract transaction/trading costs from pre-cost return
        data.strategy = data.strategy - data.trades * self.tc
        
        self.results = data
    
    def plot_results(self):
        '''  Plots the cumulative performance of the trading strategy compared to buy-and-hold.
        '''
        if self.results is None:
            print("Run test_strategy() first.")
        else:
            title = "{} | Window = {} | TC = {}".format(self.symbol, self.window, self.tc)
            self.results[["creturns", "cstrategy"]].plot(title=title, figsize=(12, 8))
            
    def optimize_strategy(self, window_range, metric = "Multiple"):
        '''
        Backtests strategy for different parameter values incl. Optimization and Reporting (Wrapper).
         
        Parameters
        ============
        window_range: tuple
            tuples of the form (start, end, step size).
        
        metric: str
            performance metric to be optimized (can be: "Multiple", "Sharpe", "Sortino", "Calmar", "Kelly")
        '''
        
        self.metric = metric
        
        if metric == "Multiple":
            performance_function = self.calculate_multiple
        elif metric == "Sharpe":
            performance_function = self.calculate_sharpe
        elif metric == "Sortino":
            performance_function = self.calculate_sortino
        elif metric == "Calmar": 
            performance_function = self.calculate_calmar
        elif metric == "Kelly": 
            performance_function = self.calculate_kelly_criterion
        
        windows = range(*window_range)
        
        performance = []
        for window in windows:
            self.prepare_data(window)
            self.run_backtest()
            performance.append(performance_function(self.results.strategy))
    
        self.results_overview =  pd.DataFrame(data = np.array(windows), columns = ["Windows"])
        self.results_overview["Performance"] = performance
        self.find_best_strategy()
        
    def find_best_strategy(self):
        ''' Finds the optimal strategy (global maximum) given the window parameter range.
        '''
        best = self.results_overview.nlargest(1, "Performance")
        window = best.Windows.iloc[0]
        perf = best.Performance.iloc[0]
        print("Windows: {} | {}: {}".format(window, self.metric, round(perf, 6))) 
        self.test_strategy(window)
        
    def visualize_many(self):
        ''' Plots parameter values vs. Performance.
        '''

        if self.results_overview is None:
            print("Run optimize_strategy() first.")
        else:
            self.results_overview.set_index("Windows", inplace = True)
            self.results_overview.plot(figsize = (12, 8))
            plt.title("Simple Contrarian Strategy | {} vs Windows".format(self.metric), fontsize = 15)
            plt.xlabel("Windows", fontsize = 15)
            plt.ylabel("{}".format(self.metric), fontsize = 15) 
            plt.show()   
            
    ############################## Performance ######################################
    
    def print_performance(self):
        ''' Calculates and prints various Performance Metrics.
        '''
        
        data = self.results.copy()
        strategy_multiple = round(self.calculate_multiple(data.strategy), 6)
        bh_multiple =       round(self.calculate_multiple(data.returns), 6)
        outperf =           round(strategy_multiple - bh_multiple, 6)
        cagr =              round(self.calculate_cagr(data.strategy), 6)
        ann_mean =          round(self.calculate_annualized_mean(data.strategy), 6)
        ann_std =           round(self.calculate_annualized_std(data.strategy), 6)
        sharpe =            round(self.calculate_sharpe(data.strategy), 6)
        sortino =           round(self.calculate_sortino(data.strategy), 6)
        max_drawdown =      round(self.calculate_max_drawdown(data.strategy), 6)
        calmar =            round(self.calculate_calmar(data.strategy), 6)
        max_dd_duration =   round(self.calculate_max_dd_duration(data.strategy), 6)
        kelly_criterion =   round(self.calculate_kelly_criterion(data.strategy), 6)
        
        print(100 * "=")
        print("SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = {} | WINDOW = {}".format(self.symbol, self.window))
        print(100 * "-")
        #print("\n")
        print("PERFORMANCE MEASURES:")
        print("\n")
        print("Multiple (Strategy):         {}".format(strategy_multiple))
        print("Multiple (Buy-and-Hold):     {}".format(bh_multiple))
        print(38 * "-")
        print("Out-/Underperformance:       {}".format(outperf))
        print("\n")
        print("CAGR:                        {}".format(cagr))
        print("Annualized Mean:             {}".format(ann_mean))
        print("Annualized Std:              {}".format(ann_std))
        print("Sharpe Ratio:                {}".format(sharpe))
        print("Sortino Ratio:               {}".format(sortino))
        print("Maximum Drawdown:            {}".format(max_drawdown))
        print("Calmar Ratio:                {}".format(calmar))
        print("Max Drawdown Duration:       {} Days".format(max_dd_duration))
        print("Kelly Criterion:             {}".format(kelly_criterion))
        
        print(100 * "=")
        
    def calculate_multiple(self, series):
        return np.exp(series.sum())
    
    def calculate_cagr(self, series):
        return np.exp(series.sum())**(1/((series.index[-1] - series.index[0]).days / 365.25)) - 1
    
    def calculate_annualized_mean(self, series):
        return series.mean() * self.tp_year
    
    def calculate_annualized_std(self, series):
        return series.std() * np.sqrt(self.tp_year)
    
    def calculate_sharpe(self, series):
        if series.std() == 0:
            return np.nan
        else:
            return series.mean() / series.std() * np.sqrt(self.tp_year)
    
    def calculate_sortino(self, series):
        excess_returns = (series - 0)
        downside_deviation = np.sqrt(np.mean(np.where(excess_returns < 0, excess_returns, 0)**2))
        if downside_deviation == 0:
            return np.nan
        else:
            sortino = (series.mean() - 0) / downside_deviation * np.sqrt(self.tp_year)
            return sortino 
    
    def calculate_max_drawdown(self, series):
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax
        max_dd = drawdown.max()
        return max_dd
    
    def calculate_calmar(self, series):
        max_dd = self.calculate_max_drawdown(series)
        if max_dd == 0:
            return np.nan
        else:
            cagr = self.calculate_cagr(series)
            calmar = cagr / max_dd
            return calmar
    
    def calculate_max_dd_duration(self, series):
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax
    
        begin = drawdown[drawdown == 0].index
        end = begin[1:]
        end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
        periods = end - begin
        max_ddd = periods.max()
        return max_ddd.days
    
    def calculate_kelly_criterion(self, series):
        series = np.exp(series) - 1
        if series.var() == 0:
            return np.nan
        else:
            return series.mean() / series.var()
    
    ############################## Performance ######################################

# %%
low_f = pd.read_csv("../Data/intraday.csv", parse_dates = ["time"], index_col = "time")
low_f

# low frequency (6h)
# Out:
#                              EURUSD
# time
# 2018-01-01 22:00:00+00:00  1.201205
# 2018-01-02 04:00:00+00:00  1.207055
# 2018-01-02 10:00:00+00:00  1.204440
# 2018-01-02 16:00:00+00:00  1.205800
# 2018-01-02 22:00:00+00:00  1.204690
# ...                             ...
# 2019-12-29 22:00:00+00:00  1.119920
# 2019-12-30 04:00:00+00:00  1.119940
# 2019-12-30 10:00:00+00:00  1.120095
# 2019-12-30 16:00:00+00:00  1.119920
# 2019-12-30 22:00:00+00:00  1.120355
#
# [2070 rows x 1 columns]

# %%
high_f = pd.read_csv("../Data/one_minute.csv", parse_dates = ["time"], index_col = "time")
high_f

# high frequency (1m)
# Out:
#                       EURUSD   GBPUSD   EURAUD
# time
# 2018-01-01 22:00:00  1.20071  1.35021  1.53836
# 2018-01-01 22:01:00  1.20068  1.35105  1.53829
# 2018-01-01 22:02:00  1.20073  1.35028  1.53834
# 2018-01-01 22:03:00  1.20072  1.35135  1.53833
# 2018-01-01 22:04:00      NaN  1.35098      NaN
# ...                      ...      ...      ...
# 2019-12-30 23:56:00      NaN  1.31136  1.59978
# 2019-12-30 23:57:00  1.12018  1.31126  1.60000
# 2019-12-30 23:58:00      NaN  1.31122  1.59994
# 2019-12-30 23:59:00  1.12013  1.31116  1.59990
# 2019-12-31 00:00:00  1.12016  1.31136  1.59952
#
# [737544 rows x 3 columns]

# %%
high_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 737544 entries, 2018-01-01 22:00:00 to 2019-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   EURUSD  693492 non-null  float64
#  1   GBPUSD  686852 non-null  float64
#  2   EURAUD  710540 non-null  float64
# dtypes: float64(3)
# memory usage: 22.5 MB

# %%
high_f.fillna(method = "ffill", inplace = True).
# Out:
#   Cell In[7], line 1
#     high_f.fillna(method = "ffill", inplace = True).
#                                                     ^
# SyntaxError: invalid syntax

# %%
high_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 737544 entries, 2018-01-01 22:00:00 to 2019-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   EURUSD  737544 non-null  float64
#  1   GBPUSD  737544 non-null  float64
#  2   EURAUD  737544 non-null  float64
# dtypes: float64(3)
# memory usage: 22.5 MB

# %%
low_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2070 entries, 2018-01-01 22:00:00+00:00 to 2019-12-30 22:00:00+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EURUSD  2070 non-null   float64
# dtypes: float64(1)
# memory usage: 96.9 KB

# %%
# Plot the low frequency data (6h)
low_f.plot(figsize = (12, 8))
plt.show()

# %%
high_f.EURUSD.plot(figsize = (12, 8))
plt.show()

# %%
low_f.loc["2018-05-01":"2018-05-05"].plot(figsize = (12, 8))
plt.show()

# %%
high_f.loc["2018-05-01":"2018-05-05", "EURUSD"].plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# __Conclusion and open Questions:__
# - 1 minute data contains __additional short-term price moves__ and __volatility__.
# - __Price Volatility__ is a __desirable attribute__ for trading. We can´t make profits if prices don´t move.
# - __More information is better__ than less information.
# - Can we __take advantage__ of the short-term volatility or is it just (patternless) __random noise__?
# - At least it __doesn´t hurt__ us, right?
# - Best Contrarian Strategy based on __1 minute data__ should be __at least as good__ as the best one based on __6h data__?

# %% [markdown]
# ---

# %% [markdown]
# # How Trading Strategies are impacted by Random Noise (Part 1)

# %% [markdown]
# __Initial Assumption: Zero Trading Costs__

# %%
symbol = "EURUSD"
start = "2018-01-01"
end = "2019-12-31"
ptc = 0 # proportional trading costs

# %% [markdown]
# __6h Data__

# %%
tester1 = ConBacktester(filepath = "../Data/intraday.csv", symbol = symbol, start = start, end = end, tc = ptc)
tester1
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13584\1939197064.py:69: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")
# ConBacktester(symbol = EURUSD, start = 2018-01-01, end = 2019-12-31)

# %%
# Find the optimal hyperparameters that optimize Multiple
tester1.optimize_strategy((1, 1001, 1), metric = "Multiple")
# Out:
# Windows: 44 | Multiple: 1.288223
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | WINDOW = 44
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.288223
# Multiple (Buy-and-Hold):     0.913293
# --------------------------------------
# Out-/Underperformance:       0.37493
#
#
# CAGR:                        0.13874
# Annualized Mean:             0.12989
# Annualized Std:              0.060266
# Sharpe Ratio:                2.155286
# Sortino Ratio:               3.346279
# Maximum Drawdown:            0.057729
# Calmar Ratio:                2.403288
# Max Drawdown Duration:       81 Days
# Kelly Criterion:             36.226556
# ====================================================================================================

# %%
tester1.plot_results()

# %% [markdown]
# __Summary__:

# %% [markdown]
# - Bar length (Frequency/Granularity): __6 hours__
# - Decision/Trading Frequency: __6 hours__
# - Decisions based on the performance of the most recent __264 hours__ (44 * 6h)

# %% [markdown]
# --

# %% [markdown]
# __1 minute Data__

# %%
tester2 = ConBacktester(filepath = "../Data/one_minute.csv", symbol = symbol, start = start, end = end, tc = ptc)
tester2
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13584\1939197064.py:69: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")
# ConBacktester(symbol = EURUSD, start = 2018-01-01, end = 2019-12-31)

# %% [markdown]
# __Plan: Re-Engineering the windows = 44 Strategy (6h) with 1 minute Data.__

# %%
window = 44
hours = 6
minutes = 60

# the optimal hyperparameter * 6 hours * 60 min

# %%
# this is windows size that chatc the rolling mean of 6 hours, 
# with given freq of 1m 
tester2.test_strategy(window = window * hours * minutes)
# Out:
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | WINDOW = 15840
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.304608
# Multiple (Buy-and-Hold):     0.913462
# --------------------------------------
# Out-/Underperformance:       0.391146
#
#
# CAGR:                        0.145928
# Annualized Mean:             0.136336
# Annualized Std:              0.067859
# Sharpe Ratio:                2.009107
# Sortino Ratio:               2.852712
# Maximum Drawdown:            0.059655
# Calmar Ratio:                2.446184
# Max Drawdown Duration:       105 Days
# Kelly Criterion:             30.10717
# ====================================================================================================

# %%
tester2.plot_results()

# %% [markdown]
# __Summary__:
#
# - Bar length (Frequency/Granularity): __1 minute__
# - Decision/Trading Frequency: __1 minute__
# - Decisions based on the performance of the most recent __264 hours__ (15,840 minutes)

# %%
tester1.plot_results()

# %% [markdown]
# __Conclusion:__
# - Can we take advantage of the short-term volatility or is it just (patternless) random noise? __A: (Small) benefit__
# - At least it doesn´t hurt us, right? __A: Correct__
# - Best Contrarian Strategy based on 1 minute data should be at least as good as the best one based on 6h data? __A: Correct__

# %% [markdown]
# <strong style="color:red">Be careful, so far we ignored trading costs</strong>!

# %% [markdown]
# ---

# %% [markdown]
# # How Trading Strategies are impacted by Random Noise (Part 2)

# %% [markdown]
# __Now with Trading Costs:__

# %%
symbol = "EURUSD"
start = "2018-01-01"
end = "2019-12-31"
ptc = 0.00007 # proportional trading costs (per trade). 
              # trade = change position

# %% [markdown]
# __6h Data__

# %%
tester1 = ConBacktester(filepath = "../Data/intraday.csv", symbol = symbol, start = start, end = end, tc = ptc)
tester1
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13584\1939197064.py:69: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")
# ConBacktester(symbol = EURUSD, start = 2018-01-01, end = 2019-12-31)

# %%
tester1.optimize_strategy((1, 1001, 1), metric = "Multiple")
# Out:
# Windows: 51 | Multiple: 1.262038
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | WINDOW = 51
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.262038
# Multiple (Buy-and-Hold):     0.915401
# --------------------------------------
# Out-/Underperformance:       0.346637
#
#
# CAGR:                        0.126996
# Annualized Mean:             0.119772
# Annualized Std:              0.059895
# Sharpe Ratio:                1.999706
# Sortino Ratio:               3.099553
# Maximum Drawdown:            0.060965
# Calmar Ratio:                2.083103
# Max Drawdown Duration:       93 Days
# Kelly Criterion:             33.85233
# ====================================================================================================

# %%
tester1.plot_results()

# %% [markdown]
# __1 minute Data__

# %%
tester2 = ConBacktester(filepath = "../Data/one_minute.csv", symbol = symbol, start = start, end = end, tc = ptc)
tester2
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13584\1939197064.py:69: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")
# ConBacktester(symbol = EURUSD, start = 2018-01-01, end = 2019-12-31)

# %% [markdown]
# __Plan: Re-Engineering the windows = 51 Strategy (6h) with 1 minute Data.__

# %%
window = 51
hours = 6
minutes = 60

# %%
tester2.test_strategy(window * hours * minutes)
# Out:
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | WINDOW = 18360
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         0.866034
# Multiple (Buy-and-Hold):     0.914767
# --------------------------------------
# Out-/Underperformance:       -0.048733
#
#
# CAGR:                        -0.071224
# Annualized Mean:             -0.074005
# Annualized Std:              0.06759
# Sharpe Ratio:                -1.094901
# Sortino Ratio:               -1.549118
# Maximum Drawdown:            0.164531
# Calmar Ratio:                -0.43289
# Max Drawdown Duration:       635 Days
# Kelly Criterion:             -15.699168
# ====================================================================================================

# %%
tester2.plot_results()
# how trading costs can change the game....

# %% [markdown]
# __Why is that?__
#
# - 1 minute Data (unsmoothed) has lots of __random noise__ (false/unprofitable trading signals)
# - leading to __excessive (and useless) trading__
# - __additional trading costs are way higher__ than the additional (small) benefits.

# %%
tester1.results.trades.value_counts()
# for 6h frequqncy (low frequency), we made:
# 2 * 142 = 284 trades
# Out:
# trades
# 0.0    1876
# 2.0     142
# Name: count, dtype: int64

# %%
tester2.results.trades.value_counts() # trading increases by a factor of 20!!!
# for im frequqncy (high frequency), we made:
# 2 * 2816 = 5632 trades !
# its bad...of curse. 
# with low freq (6h) we taken 284 trades, and made the same profit.
# when we include the trading costs, the strategy wah unprofitble!
# Out:
# trades
# 0.0    716367
# 2.0      2816
# Name: count, dtype: int64

# %%
# based on minute data, 
# 1*60*6, 1001*60*6 = 1 window of 6h, ...., 1000 window of 6h (based on 1m data freq!)  
tester2.optimize_strategy((1*60*6, 1001*60*6, 1*60*6)) # try to find optimal strategy based on 1 minute data
# Out:
# Windows: 232200 | Multiple: 1.00127
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | WINDOW = 232200
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.00127
# Multiple (Buy-and-Hold):     0.990705
# --------------------------------------
# Out-/Underperformance:       0.010565
#
#
# CAGR:                        0.000924
# Annualized Mean:             0.000929
# Annualized Std:              0.061302
# Sharpe Ratio:                0.015157
# Sortino Ratio:               0.021505
# Maximum Drawdown:            0.071229
# Calmar Ratio:                0.012968
# Max Drawdown Duration:       462 Days
# Kelly Criterion:             0.74724
# ====================================================================================================

# %%
tester2.plot_results()

# %% [markdown]
# __Conclusion:__
# - there is __no chance to find (highly) profitable simple contrarian strategies with 1 minute data__.
# - __Short term volatility__ is just (patternless) __random noise__ -> at least for the simple contrarian strategy
# - __wrong__: the higher the data frequency the better for trading (more information is better than less)
# - there must be an __optimal frequency/granularity__ for the simple contrarian strategy and the given trading cost level

# %% [markdown]
# ---

# %% [markdown]
# # Data Resampling/Smoothing and Backtesting
#
# > __Let's see how to resampling frequency and make back testing.__
#
# > __We have data with freq of 1m, and we want to resample it to 180m frequency.__

# %% [markdown]
# __Plan: Backtesting the (random) strategy with frequency = 180 minutes | window = 100__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
symbol = "EURUSD"

# %% [markdown]
# __Get Data__

# %%
data = pd.read_csv("../Data/one_minute.csv", parse_dates = ["time"], index_col = "time")
data
# Out:
#                       EURUSD   GBPUSD   EURAUD
# time
# 2018-01-01 22:00:00  1.20071  1.35021  1.53836
# 2018-01-01 22:01:00  1.20068  1.35105  1.53829
# 2018-01-01 22:02:00  1.20073  1.35028  1.53834
# 2018-01-01 22:03:00  1.20072  1.35135  1.53833
# 2018-01-01 22:04:00      NaN  1.35098      NaN
# ...                      ...      ...      ...
# 2019-12-30 23:56:00      NaN  1.31136  1.59978
# 2019-12-30 23:57:00  1.12018  1.31126  1.60000
# 2019-12-30 23:58:00      NaN  1.31122  1.59994
# 2019-12-30 23:59:00  1.12013  1.31116  1.59990
# 2019-12-31 00:00:00  1.12016  1.31136  1.59952
#
# [737544 rows x 3 columns]

# %%
data = data[symbol].to_frame().fillna(method = "ffill")
data

# the data with frequency of 1m
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13584\3883284511.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data[symbol].to_frame().fillna(method = "ffill")
#                       EURUSD
# time
# 2018-01-01 22:00:00  1.20071
# 2018-01-01 22:01:00  1.20068
# 2018-01-01 22:02:00  1.20073
# 2018-01-01 22:03:00  1.20072
# 2018-01-01 22:04:00  1.20072
# ...                      ...
# 2019-12-30 23:56:00  1.12018
# 2019-12-30 23:57:00  1.12018
# 2019-12-30 23:58:00  1.12018
# 2019-12-30 23:59:00  1.12013
# 2019-12-31 00:00:00  1.12016
#
# [737544 rows x 1 columns]

# %%
data.rename(columns = {symbol:"price"}, inplace = True)

# %%
data
# Out:
#                        price
# time
# 2018-01-01 22:00:00  1.20071
# 2018-01-01 22:01:00  1.20068
# 2018-01-01 22:02:00  1.20073
# 2018-01-01 22:03:00  1.20072
# 2018-01-01 22:04:00  1.20072
# ...                      ...
# 2019-12-30 23:56:00  1.12018
# 2019-12-30 23:57:00  1.12018
# 2019-12-30 23:58:00  1.12018
# 2019-12-30 23:59:00  1.12013
# 2019-12-31 00:00:00  1.12016
#
# [737544 rows x 1 columns]

# %%
data["returns"] = np.log(data.price / data.price.shift(1))
data

# still the data with freq of 1m.
# Out:
#                        price   returns
# time
# 2018-01-01 22:00:00  1.20071       NaN
# 2018-01-01 22:01:00  1.20068 -0.000025
# 2018-01-01 22:02:00  1.20073  0.000042
# 2018-01-01 22:03:00  1.20072 -0.000008
# 2018-01-01 22:04:00  1.20072  0.000000
# ...                      ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000
# 2019-12-30 23:57:00  1.12018  0.000000
# 2019-12-30 23:58:00  1.12018  0.000000
# 2019-12-30 23:59:00  1.12013 -0.000045
# 2019-12-31 00:00:00  1.12016  0.000027
#
# [737544 rows x 2 columns]

# %% [markdown]
# __Prepare Data__

# %%
# define the frequenct and the window size
freq = 180
freq = "{}min".format(freq)
window = 100

# %%
freq
# Out:
# '180min'

# %% [markdown]
# __resample the data:__
# - From freq of 1m --> to freq of 180m!

# %%
# resample the data (from 1m freq to 180m freq):
# `resample(freq)` => resample to freq of 180,
# `last()` take the most last data point (the last close price).
resamp = data.price.to_frame().resample(freq).last().dropna().iloc[:-1]
resamp

# Note: 
# - with data frequqncy of 1m, we have 737544 rows.
# - now, with data frequqncy of 180m, we have 4182 rows
# Out:
#                        price
# time
# 2018-01-01 21:00:00  1.20108
# 2018-01-02 00:00:00  1.20096
# 2018-01-02 03:00:00  1.20245
# 2018-01-02 06:00:00  1.20450
# 2018-01-02 09:00:00  1.20594
# ...                      ...
# 2019-12-30 09:00:00  1.11916
# 2019-12-30 12:00:00  1.12058
# 2019-12-30 15:00:00  1.12107
# 2019-12-30 18:00:00  1.11985
# 2019-12-30 21:00:00  1.12013
#
# [4182 rows x 1 columns]

# %% [markdown]
# - use last() to get a bar´s close price
# - dropna() removes NaNs on weekends and bank holidays (resample() creates ALL 180m bars)
# - the last bar is typically incomplete -> iloc[:-1]
# - Index: It´s the starting time (open) of the bars

# %%
window
# Out:
# 100

# %%
# Now, lets compute the log returns to the re sample data: 

# compute the lod return
resamp["returns"] = np.log(resamp / resamp.shift(1))
# compute the rolling mean return
resamp["roll_return"] = resamp["returns"].rolling(window).mean()
resamp

# the resamp data with freq of 180m
# Out:
#                        price   returns  roll_return
# time
# 2018-01-01 21:00:00  1.20108       NaN          NaN
# 2018-01-02 00:00:00  1.20096 -0.000100          NaN
# 2018-01-02 03:00:00  1.20245  0.001240          NaN
# 2018-01-02 06:00:00  1.20450  0.001703          NaN
# 2018-01-02 09:00:00  1.20594  0.001195          NaN
# ...                      ...       ...          ...
# 2019-12-30 09:00:00  1.11916 -0.000482     0.000098
# 2019-12-30 12:00:00  1.12058  0.001268     0.000103
# 2019-12-30 15:00:00  1.12107  0.000437     0.000106
# 2019-12-30 18:00:00  1.11985 -0.001089     0.000053
# 2019-12-30 21:00:00  1.12013  0.000250     0.000062
#
# [4182 rows x 3 columns]

# %%
# apply the contrarian strategy 
resamp["position"] = -np.sign(resamp["roll_return"])
resamp
# Out:
#                        price   returns  roll_return  position
# time
# 2018-01-01 21:00:00  1.20108       NaN          NaN       NaN
# 2018-01-02 00:00:00  1.20096 -0.000100          NaN       NaN
# 2018-01-02 03:00:00  1.20245  0.001240          NaN       NaN
# 2018-01-02 06:00:00  1.20450  0.001703          NaN       NaN
# 2018-01-02 09:00:00  1.20594  0.001195          NaN       NaN
# ...                      ...       ...          ...       ...
# 2019-12-30 09:00:00  1.11916 -0.000482     0.000098      -1.0
# 2019-12-30 12:00:00  1.12058  0.001268     0.000103      -1.0
# 2019-12-30 15:00:00  1.12107  0.000437     0.000106      -1.0
# 2019-12-30 18:00:00  1.11985 -0.001089     0.000053      -1.0
# 2019-12-30 21:00:00  1.12013  0.000250     0.000062      -1.0
#
# [4182 rows x 4 columns]

# %%
# Drop NaN 
resamp = resamp.dropna()
resamp
# Out:
#                        price   returns  roll_return  position
# time
# 2018-01-18 03:00:00  1.22070  0.001041     0.000162      -1.0
# 2018-01-18 06:00:00  1.22040 -0.000246     0.000161      -1.0
# 2018-01-18 09:00:00  1.22400  0.002946     0.000178      -1.0
# 2018-01-18 12:00:00  1.22606  0.001682     0.000177      -1.0
# 2018-01-18 15:00:00  1.22283 -0.002638     0.000139      -1.0
# ...                      ...       ...          ...       ...
# 2019-12-30 09:00:00  1.11916 -0.000482     0.000098      -1.0
# 2019-12-30 12:00:00  1.12058  0.001268     0.000103      -1.0
# 2019-12-30 15:00:00  1.12107  0.000437     0.000106      -1.0
# 2019-12-30 18:00:00  1.11985 -0.001089     0.000053      -1.0
# 2019-12-30 21:00:00  1.12013  0.000250     0.000062      -1.0
#
# [4082 rows x 4 columns]

# %% [markdown]
# -> First Trade at __2018-01-18 06:00:00__ (short / -1) for the bar from 2018-01-18 06:00:00 until 2018-01-18 09:00:00

# %% [markdown]
# ---

# %% [markdown]
# # Upsample back
#
# > Now, let's take the data that we resample (from 1m to 180m freq), __and resample back to 1m (from 180m --> 1m freq)__

# %% [markdown]
# __Goal: Copy the trading positions back into the 1 minute Dataset. ("upsampling")__

# %% [markdown]
# -> In the 1 minute Dataset, first Trade at __2018-01-18 06:00:00__ needs to be __indicated by the bar starting at 2018-01-18 05:59:00__

# %%
begin = "2018-01-18 05:59:00"
begin
# Out:
# '2018-01-18 05:59:00'

# %%
data = data.loc[begin:].copy()
data

# we want convert the `resamp` Dataframe to the 1m freq, like in this df:   

# this is the original data, with freq of 1m
# Out:
#                        price   returns
# time
# 2018-01-18 05:59:00  1.22070  0.000156
# 2018-01-18 06:00:00  1.22059 -0.000090
# 2018-01-18 06:01:00  1.22065  0.000049
# 2018-01-18 06:02:00  1.22064 -0.000008
# 2018-01-18 06:03:00  1.22064  0.000000
# ...                      ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000
# 2019-12-30 23:57:00  1.12018  0.000000
# 2019-12-30 23:58:00  1.12018  0.000000
# 2019-12-30 23:59:00  1.12013 -0.000045
# 2019-12-31 00:00:00  1.12016  0.000027
#
# [719832 rows x 2 columns]

# %%
# Can we upsample that back to 1m freq? (from 180m freq ro 1m freq)
resamp

# this is the resample data, 180m freq
# Out:
#                        price   returns  roll_return  position
# time
# 2018-01-18 03:00:00  1.22070  0.001041     0.000162      -1.0
# 2018-01-18 06:00:00  1.22040 -0.000246     0.000161      -1.0
# 2018-01-18 09:00:00  1.22400  0.002946     0.000178      -1.0
# 2018-01-18 12:00:00  1.22606  0.001682     0.000177      -1.0
# 2018-01-18 15:00:00  1.22283 -0.002638     0.000139      -1.0
# ...                      ...       ...          ...       ...
# 2019-12-30 09:00:00  1.11916 -0.000482     0.000098      -1.0
# 2019-12-30 12:00:00  1.12058  0.001268     0.000103      -1.0
# 2019-12-30 15:00:00  1.12107  0.000437     0.000106      -1.0
# 2019-12-30 18:00:00  1.11985 -0.001089     0.000053      -1.0
# 2019-12-30 21:00:00  1.12013  0.000250     0.000062      -1.0
#
# [4082 rows x 4 columns]

# %%
resamp.position.shift()
# Out:
# time
# 2018-01-18 03:00:00    NaN
# 2018-01-18 06:00:00   -1.0
# 2018-01-18 09:00:00   -1.0
# 2018-01-18 12:00:00   -1.0
# 2018-01-18 15:00:00   -1.0
#                       ...
# 2019-12-30 09:00:00   -1.0
# 2019-12-30 12:00:00   -1.0
# 2019-12-30 15:00:00   -1.0
# 2019-12-30 18:00:00   -1.0
# 2019-12-30 21:00:00   -1.0
# Name: position, Length: 4082, dtype: float64

# %%
# becase the data contain the historical price of [begin:] (one step ahead),
# we shift also the positions one step ahead. 

# copy this shifted positions back into back into the one minute dataset.
# the 1m freq data get the position of 180m freq (shifted by 1)
data["position"] = resamp.position.shift()
data

# What we did here?
# we take the positions in the resample data (180m freq), and store the positions (by the date index)
# in the data with frequency of 1m.

# that's the reasson that we see in the exact time that was in both (in 180m and 1m) positions,
# and in the other times NaN. 
# e.g.: 2018-01-18 06:00:00	===> is a date that was also in 180m freq and also 1m freq.
# Out:
#                        price   returns  position
# time
# 2018-01-18 05:59:00  1.22070  0.000156       NaN
# 2018-01-18 06:00:00  1.22059 -0.000090      -1.0
# 2018-01-18 06:01:00  1.22065  0.000049       NaN
# 2018-01-18 06:02:00  1.22064 -0.000008       NaN
# 2018-01-18 06:03:00  1.22064  0.000000       NaN
# ...                      ...       ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000       NaN
# 2019-12-30 23:57:00  1.12018  0.000000       NaN
# 2019-12-30 23:58:00  1.12018  0.000000       NaN
# 2019-12-30 23:59:00  1.12013 -0.000045       NaN
# 2019-12-31 00:00:00  1.12016  0.000027       NaN
#
# [719832 rows x 3 columns]

# %%
# just to ilustrate:
data.position.shift(-1)
# Out:
# time
# 2018-01-18 05:59:00   -1.0
# 2018-01-18 06:00:00    NaN
# 2018-01-18 06:01:00    NaN
# 2018-01-18 06:02:00    NaN
# 2018-01-18 06:03:00    NaN
#                       ...
# 2019-12-30 23:56:00    NaN
# 2019-12-30 23:57:00    NaN
# 2019-12-30 23:58:00    NaN
# 2019-12-30 23:59:00    NaN
# 2019-12-31 00:00:00    NaN
# Name: position, Length: 719832, dtype: float64

# %%
data.position.shift(-1).ffill()
# Out:
# time
# 2018-01-18 05:59:00   -1.0
# 2018-01-18 06:00:00   -1.0
# 2018-01-18 06:01:00   -1.0
# 2018-01-18 06:02:00   -1.0
# 2018-01-18 06:03:00   -1.0
#                       ...
# 2019-12-30 23:56:00   -1.0
# 2019-12-30 23:57:00   -1.0
# 2019-12-30 23:58:00   -1.0
# 2019-12-30 23:59:00   -1.0
# 2019-12-31 00:00:00   -1.0
# Name: position, Length: 719832, dtype: float64

# %%
# shift back one bar and then forward fill for the next 180 minutes
data.position = data.position.shift(-1).ffill()

# %%
data

# And now, we sucess to marage the position of the 180m freq back to a position of 1m freq! 
# we fill the nan with the same values between the positions!
# Out:
#                        price   returns  position
# time
# 2018-01-18 05:59:00  1.22070  0.000156      -1.0
# 2018-01-18 06:00:00  1.22059 -0.000090      -1.0
# 2018-01-18 06:01:00  1.22065  0.000049      -1.0
# 2018-01-18 06:02:00  1.22064 -0.000008      -1.0
# 2018-01-18 06:03:00  1.22064  0.000000      -1.0
# ...                      ...       ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000      -1.0
# 2019-12-30 23:57:00  1.12018  0.000000      -1.0
# 2019-12-30 23:58:00  1.12018  0.000000      -1.0
# 2019-12-30 23:59:00  1.12013 -0.000045      -1.0
# 2019-12-31 00:00:00  1.12016  0.000027      -1.0
#
# [719832 rows x 3 columns]

# %% [markdown]
# __and now we can Backtest__

# %%
data["strategy"] = data["position"].shift(1) * data["returns"]
data
# Out:
#                        price   returns  position  strategy
# time
# 2018-01-18 05:59:00  1.22070  0.000156      -1.0       NaN
# 2018-01-18 06:00:00  1.22059 -0.000090      -1.0  0.000090
# 2018-01-18 06:01:00  1.22065  0.000049      -1.0 -0.000049
# 2018-01-18 06:02:00  1.22064 -0.000008      -1.0  0.000008
# 2018-01-18 06:03:00  1.22064  0.000000      -1.0 -0.000000
# ...                      ...       ...       ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000      -1.0 -0.000000
# 2019-12-30 23:57:00  1.12018  0.000000      -1.0 -0.000000
# 2019-12-30 23:58:00  1.12018  0.000000      -1.0 -0.000000
# 2019-12-30 23:59:00  1.12013 -0.000045      -1.0  0.000045
# 2019-12-31 00:00:00  1.12016  0.000027      -1.0 -0.000027
#
# [719832 rows x 4 columns]

# %%
ptc = 0.00007

# %%
data["trades"] = data.position.diff().fillna(0).abs()
data.strategy = data.strategy - data.trades * ptc

# %%
data
# Out:
#                        price   returns  position  strategy  trades
# time
# 2018-01-18 05:59:00  1.22070  0.000156      -1.0       NaN     0.0
# 2018-01-18 06:00:00  1.22059 -0.000090      -1.0  0.000090     0.0
# 2018-01-18 06:01:00  1.22065  0.000049      -1.0 -0.000049     0.0
# 2018-01-18 06:02:00  1.22064 -0.000008      -1.0  0.000008     0.0
# 2018-01-18 06:03:00  1.22064  0.000000      -1.0 -0.000000     0.0
# ...                      ...       ...       ...       ...     ...
# 2019-12-30 23:56:00  1.12018  0.000000      -1.0 -0.000000     0.0
# 2019-12-30 23:57:00  1.12018  0.000000      -1.0 -0.000000     0.0
# 2019-12-30 23:58:00  1.12018  0.000000      -1.0 -0.000000     0.0
# 2019-12-30 23:59:00  1.12013 -0.000045      -1.0  0.000045     0.0
# 2019-12-31 00:00:00  1.12016  0.000027      -1.0 -0.000027     0.0
#
# [719832 rows x 5 columns]

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)

# %%
data.dropna()
# Out:
#                        price   returns  position  strategy  trades  creturns  \
# time
# 2018-01-18 06:00:00  1.22059 -0.000090      -1.0  0.000090     0.0  1.000066
# 2018-01-18 06:01:00  1.22065  0.000049      -1.0 -0.000049     0.0  1.000115
# 2018-01-18 06:02:00  1.22064 -0.000008      -1.0  0.000008     0.0  1.000107
# 2018-01-18 06:03:00  1.22064  0.000000      -1.0 -0.000000     0.0  1.000107
# 2018-01-18 06:04:00  1.22039 -0.000205      -1.0  0.000205     0.0  0.999902
# ...                      ...       ...       ...       ...     ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000      -1.0 -0.000000     0.0  0.917797
# 2019-12-30 23:57:00  1.12018  0.000000      -1.0 -0.000000     0.0  0.917797
# 2019-12-30 23:58:00  1.12018  0.000000      -1.0 -0.000000     0.0  0.917797
# 2019-12-30 23:59:00  1.12013 -0.000045      -1.0  0.000045     0.0  0.917756
# 2019-12-31 00:00:00  1.12016  0.000027      -1.0 -0.000027     0.0  0.917780
#
#                      cstrategy
# time
# 2018-01-18 06:00:00   1.000090
# 2018-01-18 06:01:00   1.000041
# 2018-01-18 06:02:00   1.000049
# 2018-01-18 06:03:00   1.000049
# 2018-01-18 06:04:00   1.000254
# ...                        ...
# 2019-12-30 23:56:00   1.179765
# 2019-12-30 23:57:00   1.179765
# 2019-12-30 23:58:00   1.179765
# 2019-12-30 23:59:00   1.179818
# 2019-12-31 00:00:00   1.179787
#
# [719831 rows x 7 columns]

# %%
data[["creturns", "cstrategy"]].plot(figsize = (12, 8), fontsize = 13)
plt.title("Freq = {} | Window = {}".format(freq, window), fontsize = 15)
plt.show()

# %%
data.trades.value_counts()
# Out:
# trades
# 0.0    719602
# 2.0       230
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Updating the ConBacktester Class (Smoothing)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
# Version 4.0 (Smoothing)

class ConBacktester():
    ''' Class for the vectorized backtesting of simple contrarian trading strategies.
    
    Attributes
    ============
    filepath: str
        local filepath of the dataset (csv-file)
    symbol: str
        ticker symbol (instrument) to be backtested
    start: str
        start date for data import
    end: str
        end date for data import
    tc: float
        proportional trading costs per trade
    
    
    Methods
    =======
    get_data:
        imports the data.
        
    test_strategy:
        prepares the data and backtests the trading strategy incl. reporting (wrapper).
        
    prepare_data:
        prepares the data for backtesting.
    
    run_backtest:
        runs the strategy backtest.
    
    upsample:
        upsamples/copies trading positions back to higher frequency.
        
    plot_results:
        plots the cumulative performance of the trading strategy compared to buy-and-hold.
        
    optimize_strategy:
        backtests strategy for different parameter values incl. optimization and reporting (wrapper).
    
    find_best_strategy:
        finds the optimal strategy (global maximum) given the window parameter range.
        
    visualize_many:
        plots parameter values vs. performance. 
        
    print_performance:
        calculates and prints various performance metrics.
        
    '''    
    
    def __init__(self, filepath, symbol, start, end, tc):
        
        self.filepath = filepath
        self.symbol = symbol
        self.start = start
        self.end = end
        self.tc = tc
        self.results = None
        self.get_data()
        self.tp_year = (self.data.price.count() / ((self.data.index[-1] - self.data.index[0]).days / 365.25))
        
    def __repr__(self):
        return "ConBacktester(symbol = {}, start = {}, end = {})".format(self.symbol, self.start, self.end)
        
    def get_data(self):
        ''' Imports the data.
        '''
        raw = pd.read_csv(self.filepath, parse_dates = ["time"], index_col = "time")
        raw = raw[self.symbol].to_frame().fillna(method = "ffill")
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw.price / raw.price.shift(1))
        self.data = raw
        
    def test_strategy(self, freq = 60, window = 1): # added : freq
        '''
        Prepares the data and backtests the trading strategy incl. reporting (Wrapper).
         
        Parameters
        ============
        freq: int
            data frequency/granularity to work with (in minutes)
        
        window: int
            time window (number of bars) to be considered for the strategy.
        '''
        self.freq = "{}min".format(freq) # new
        self.window = window
                                
        self.prepare_data(freq, window) # added: freq
        self.upsample() # new
        self.run_backtest()
        
        data = self.results.copy()
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data
        
        self.print_performance()
    
    def prepare_data(self, freq, window): # added: freq
        ''' Prepares the Data for Backtesting.
        '''
        # NEW/UPDATED
        data = self.data.price.to_frame().copy()
        freq = "{}min".format(freq)
        resamp = data.resample(freq).last().dropna().iloc[:-1]
        resamp["returns"] = np.log(resamp / resamp.shift(1))
        resamp["roll_return"] = resamp["returns"].rolling(window).mean()
        resamp["position"] = -np.sign(resamp["roll_return"])
        resamp.dropna(inplace = True)
        self.results = resamp
        return resamp 
    
    def run_backtest(self):
        ''' Runs the strategy backtest.
        '''
        
        data = self.results.copy()
        data["strategy"] = data["position"].shift(1) * data["returns"]
        
        # determine the number of trades in each bar
        data["trades"] = data.position.diff().fillna(0).abs()
        
        # subtract transaction/trading costs from pre-cost return
        data.strategy = data.strategy - data.trades * self.tc
        
        self.results = data
        
    def upsample(self): # NEW!!!
        '''  Upsamples/copies trading positions back to higher frequency.
        '''
        
        data = self.data.copy()
        resamp = self.results.copy()
               
        data["position"] = resamp.position.shift()
        data = data.loc[resamp.index[0]:].copy()
        data.position = data.position.shift(-1).ffill()
        data.dropna(inplace=True)
        self.results = data
    
    def plot_results(self):
        '''  Plots the cumulative performance of the trading strategy compared to buy-and-hold.
        '''
        if self.results is None:
            print("Run test_strategy() first.")
        else:
            title = "{} | Freq = {} | Window = {} | TC = {}".format(self.symbol, self.freq, self.window, self.tc)
            self.results[["creturns", "cstrategy"]].plot(title=title, figsize=(12, 8))
            
    def optimize_strategy(self, window_range, metric = "Multiple"):
        '''
        Backtests strategy for different parameter values incl. Optimization and Reporting (Wrapper).
         
        Parameters
        ============
        window_range: tuple
            tuples of the form (start, end, step size).
        
        metric: str
            performance metric to be optimized (can be: "Multiple", "Sharpe", "Sortino", "Calmar", "Kelly")
        '''
        
        self.metric = metric
        
        if metric == "Multiple":
            performance_function = self.calculate_multiple
        elif metric == "Sharpe":
            performance_function = self.calculate_sharpe
        elif metric == "Sortino":
            performance_function = self.calculate_sortino
        elif metric == "Calmar": 
            performance_function = self.calculate_calmar
        elif metric == "Kelly": 
            performance_function = self.calculate_kelly_criterion
        
        windows = range(*window_range)
        
        performance = []
        for window in windows:
            self.prepare_data(window)
            self.run_backtest()
            performance.append(performance_function(self.results.strategy))
    
        self.results_overview =  pd.DataFrame(data = np.array(windows), columns = ["Windows"])
        self.results_overview["Performance"] = performance
        self.find_best_strategy()
        
    def find_best_strategy(self):
        ''' Finds the optimal strategy (global maximum) given the window parameter range.
        '''
        best = self.results_overview.nlargest(1, "Performance")
        window = best.Windows.iloc[0]
        perf = best.Performance.iloc[0]
        print("Windows: {} | {}: {}".format(window, self.metric, round(perf, 6))) 
        self.test_strategy(window)
        
    def visualize_many(self):
        ''' Plots parameter values vs. Performance.
        '''

        if self.results_overview is None:
            print("Run optimize_strategy() first.")
        else:
            self.results_overview.set_index("Windows", inplace = True)
            self.results_overview.plot(figsize = (12, 8))
            plt.title("Simple Contrarian Strategy | {} vs Windows".format(self.metric), fontsize = 15)
            plt.xlabel("Windows", fontsize = 15)
            plt.ylabel("{}".format(self.metric), fontsize = 15) 
            plt.show()   
            
    ############################## Performance ######################################
    
    def print_performance(self):
        ''' Calculates and prints various Performance Metrics.
        '''
        
        data = self.results.copy()
        strategy_multiple = round(self.calculate_multiple(data.strategy), 6)
        bh_multiple =       round(self.calculate_multiple(data.returns), 6)
        outperf =           round(strategy_multiple - bh_multiple, 6)
        cagr =              round(self.calculate_cagr(data.strategy), 6)
        ann_mean =          round(self.calculate_annualized_mean(data.strategy), 6)
        ann_std =           round(self.calculate_annualized_std(data.strategy), 6)
        sharpe =            round(self.calculate_sharpe(data.strategy), 6)
        sortino =           round(self.calculate_sortino(data.strategy), 6)
        max_drawdown =      round(self.calculate_max_drawdown(data.strategy), 6)
        calmar =            round(self.calculate_calmar(data.strategy), 6)
        max_dd_duration =   round(self.calculate_max_dd_duration(data.strategy), 6)
        kelly_criterion =   round(self.calculate_kelly_criterion(data.strategy), 6)
        
        print(100 * "=")
        print("SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = {} | Freq: {} | WINDOW = {}".format(self.symbol, self.freq, self.window))
        print(100 * "-")
        #print("\n")
        print("PERFORMANCE MEASURES:")
        print("\n")
        print("Multiple (Strategy):         {}".format(strategy_multiple))
        print("Multiple (Buy-and-Hold):     {}".format(bh_multiple))
        print(38 * "-")
        print("Out-/Underperformance:       {}".format(outperf))
        print("\n")
        print("CAGR:                        {}".format(cagr))
        print("Annualized Mean:             {}".format(ann_mean))
        print("Annualized Std:              {}".format(ann_std))
        print("Sharpe Ratio:                {}".format(sharpe))
        print("Sortino Ratio:               {}".format(sortino))
        print("Maximum Drawdown:            {}".format(max_drawdown))
        print("Calmar Ratio:                {}".format(calmar))
        print("Max Drawdown Duration:       {} Days".format(max_dd_duration))
        print("Kelly Criterion:             {}".format(kelly_criterion))
        
        print(100 * "=")
        
    def calculate_multiple(self, series):
        return np.exp(series.sum())
    
    def calculate_cagr(self, series):
        return np.exp(series.sum())**(1/((series.index[-1] - series.index[0]).days / 365.25)) - 1
    
    def calculate_annualized_mean(self, series):
        return series.mean() * self.tp_year
    
    def calculate_annualized_std(self, series):
        return series.std() * np.sqrt(self.tp_year)
    
    def calculate_sharpe(self, series):
        if series.std() == 0:
            return np.nan
        else:
            return series.mean() / series.std() * np.sqrt(self.tp_year)
    
    def calculate_sortino(self, series):
        excess_returns = (series - 0)
        downside_deviation = np.sqrt(np.mean(np.where(excess_returns < 0, excess_returns, 0)**2))
        if downside_deviation == 0:
            return np.nan
        else:
            sortino = (series.mean() - 0) / downside_deviation * np.sqrt(self.tp_year)
            return sortino 
    
    def calculate_max_drawdown(self, series):
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax
        max_dd = drawdown.max()
        return max_dd
    
    def calculate_calmar(self, series):
        max_dd = self.calculate_max_drawdown(series)
        if max_dd == 0:
            return np.nan
        else:
            cagr = self.calculate_cagr(series)
            calmar = cagr / max_dd
            return calmar
    
    def calculate_max_dd_duration(self, series):
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax
    
        begin = drawdown[drawdown == 0].index
        end = begin[1:]
        end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
        periods = end - begin
        max_ddd = periods.max()
        return max_ddd.days
    
    def calculate_kelly_criterion(self, series):
        series = np.exp(series) - 1
        if series.var() == 0:
            return np.nan
        else:
            return series.mean() / series.var()
    
    ############################## Performance ######################################

# %%
filepath = "../Data/one_minute.csv"
symbol = "EURUSD"
start = "2018-01-01"
end = "2019-12-31"
ptc = 0.00007

# %%
tester = ConBacktester(filepath = filepath, symbol = symbol, start = start, end = end, tc = ptc)
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13272\1930133960.py:72: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")

# %%
tester.data
# Out:
#                        price   returns
# time
# 2018-01-01 22:00:00  1.20071       NaN
# 2018-01-01 22:01:00  1.20068 -0.000025
# 2018-01-01 22:02:00  1.20073  0.000042
# 2018-01-01 22:03:00  1.20072 -0.000008
# 2018-01-01 22:04:00  1.20072  0.000000
# ...                      ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000
# 2019-12-30 23:57:00  1.12018  0.000000
# 2019-12-30 23:58:00  1.12018  0.000000
# 2019-12-30 23:59:00  1.12013 -0.000045
# 2019-12-31 00:00:00  1.12016  0.000027
#
# [737544 rows x 2 columns]

# %%
# Test with two hyperparameters:
# freq ---> the data freqency (eg. bars freq of 180m - each bar is 180m.)
# window ---> the size of rolling mean 
tester.test_strategy(freq = 180, window = 100)
# Out:
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | Freq: 180min | WINDOW = 100
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.179787
# Multiple (Buy-and-Hold):     0.91778
# --------------------------------------
# Out-/Underperformance:       0.262007
#
#
# CAGR:                        0.088645
# Annualized Mean:             0.084992
# Annualized Std:              0.067755
# Sharpe Ratio:                1.254397
# Sortino Ratio:               1.784619
# Maximum Drawdown:            0.065602
# Calmar Ratio:                1.351261
# Max Drawdown Duration:       156 Days
# Kelly Criterion:             19.01357
# ====================================================================================================

# %%
tester.results
# Out:
#                        price   returns  position  strategy  trades  creturns  \
# time
# 2018-01-18 05:59:00  1.22070  0.000156      -1.0       NaN     0.0  1.000156
# 2018-01-18 06:00:00  1.22059 -0.000090      -1.0  0.000090     0.0  1.000066
# 2018-01-18 06:01:00  1.22065  0.000049      -1.0 -0.000049     0.0  1.000115
# 2018-01-18 06:02:00  1.22064 -0.000008      -1.0  0.000008     0.0  1.000107
# 2018-01-18 06:03:00  1.22064  0.000000      -1.0 -0.000000     0.0  1.000107
# ...                      ...       ...       ...       ...     ...       ...
# 2019-12-30 23:56:00  1.12018  0.000000      -1.0 -0.000000     0.0  0.917797
# 2019-12-30 23:57:00  1.12018  0.000000      -1.0 -0.000000     0.0  0.917797
# 2019-12-30 23:58:00  1.12018  0.000000      -1.0 -0.000000     0.0  0.917797
# 2019-12-30 23:59:00  1.12013 -0.000045      -1.0  0.000045     0.0  0.917756
# 2019-12-31 00:00:00  1.12016  0.000027      -1.0 -0.000027     0.0  0.917780
#
#                      cstrategy
# time
# 2018-01-18 05:59:00        NaN
# 2018-01-18 06:00:00   1.000090
# 2018-01-18 06:01:00   1.000041
# 2018-01-18 06:02:00   1.000049
# 2018-01-18 06:03:00   1.000049
# ...                        ...
# 2019-12-30 23:56:00   1.179765
# 2019-12-30 23:57:00   1.179765
# 2019-12-30 23:58:00   1.179765
# 2019-12-30 23:59:00   1.179818
# 2019-12-31 00:00:00   1.179787
#
# [719832 rows x 7 columns]

# %%
tester.plot_results()

# %% [markdown]
# ---

# %% [markdown]
# # Two Parameter Optimization: `Frequency` and `Window`

# %%
from itertools import product
import seaborn as sns

# %%
filepath = "../Data/one_minute.csv"
symbol = "EURUSD"
start = "2018-01-01"
end = "2019-12-31"
ptc = 0.00007

# %%
tester = ConBacktester(filepath = filepath, 
                       symbol = symbol, 
                       start = start, 
                       end = end, 
                       tc = ptc)
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13272\1930133960.py:72: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")

# %%
tester.test_strategy(freq = 180, window = 100)
# Out:
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | Freq: 180min | WINDOW = 100
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.179787
# Multiple (Buy-and-Hold):     0.91778
# --------------------------------------
# Out-/Underperformance:       0.262007
#
#
# CAGR:                        0.088645
# Annualized Mean:             0.084992
# Annualized Std:              0.067755
# Sharpe Ratio:                1.254397
# Sortino Ratio:               1.784619
# Maximum Drawdown:            0.065602
# Calmar Ratio:                1.351261
# Max Drawdown Duration:       156 Days
# Kelly Criterion:             19.01357
# ====================================================================================================

# %%
# Define frequenct range (51, 61,...,301) 
freq_range = (51, 300, 10)
freqs = range(*freq_range)
freqs
# Out:
# range(51, 300, 10)

# %%
# Defind window range
window_range = (51, 300, 10)
windows = range(*window_range)
windows
# Out:
# range(51, 300, 10)

# %%
len(list(windows))
# Out:
# 25

# %%
# Give me all possible combinations of the hyperparameters 
combinations = list(product(freqs, windows))
combinations[:10]
# Out:
# [(51, 51),
#  (51, 61),
#  (51, 71),
#  (51, 81),
#  (51, 91),
#  (51, 101),
#  (51, 111),
#  (51, 121),
#  (51, 131),
#  (51, 141)]

# %%
print(len(combinations), "di")
# Out:
# 625

# %%
# Test all the possible combinations

performance = []

for comb in combinations: # for each combination 
    tester.prepare_data(comb[0], comb[1]) # prepare the data 
    tester.upsample() # re-sample
    tester.run_backtest() # run the strategy
    # calculate the multiple
    performance.append(tester.calculate_multiple(tester.results.strategy))

# %%
len(performance), performance[:10]
# Out:
# (625,
#  [0.8449724524229771,
#   0.872033949298535,
#   0.8802226013036503,
#   0.898820835820167,
#   0.9253520989807986,
#   0.8925789828221117,
#   0.9171483255628511,
#   0.9192192922837764,
#   1.0076731272707107,
#   0.9905630393300178])

# %%
results_overview =  pd.DataFrame(data = np.array(combinations), 
                                 columns = ["Freq", "Windows"])
results_overview
# Out:
#      Freq  Windows
# 0      51       51
# 1      51       61
# 2      51       71
# 3      51       81
# 4      51       91
# ..    ...      ...
# 620   291      251
# 621   291      261
# 622   291      271
# 623   291      281
# 624   291      291
#
# [625 rows x 2 columns]

# %%
results_overview["Performance"] = performance
results_overview
# Out:
#      Freq  Windows  Performance
# 0      51       51     0.844972
# 1      51       61     0.872034
# 2      51       71     0.880223
# 3      51       81     0.898821
# 4      51       91     0.925352
# ..    ...      ...          ...
# 620   291      251     1.024589
# 621   291      261     1.077344
# 622   291      271     1.031718
# 623   291      281     1.004028
# 624   291      291     1.029904
#
# [625 rows x 3 columns]

# %%
# Show the top 10 perfoemance and thier hyperparameters. 
results_overview.nlargest(10, "Performance")
# Out:
#      Freq  Windows  Performance
# 380   201      101     1.412225
# 258   151      131     1.347173
# 307   171      121     1.324477
# 163   111      181     1.323788
# 404   211       91     1.321807
# 331   181      111     1.318309
# 602   291       71     1.313675
# 210   131      151     1.306025
# 552   271       71     1.300831
# 478   241       81     1.294582

# %%
# Show the performace results of all the possible hyperparameter combination

# pivot: Reshape data (produce a "pivot" table) based on column values.
matrix = results_overview.pivot(index = "Freq", 
                                columns = "Windows", 
                                values = "Performance")
matrix
# Out:
# Windows       51        61        71        81        91        101       111  \
# Freq
# 51       0.844972  0.872034  0.880223  0.898821  0.925352  0.892579  0.917148
# 61       0.902229  0.855305  0.858636  0.895569  0.868934  0.922762  1.009180
# 71       0.865919  0.848310  0.874528  0.913028  1.005389  0.999504  1.035826
# 81       0.930111  0.926289  0.860536  0.980358  1.019838  1.072307  1.026823
# 91       0.923512  0.913409  0.984759  1.023579  1.024948  1.050117  1.049250
# 101      0.884209  0.941890  0.976067  1.045988  1.109496  1.097421  1.158496
# 111      0.945783  1.040548  1.019063  1.072413  1.046363  1.146547  1.130198
# 121      0.970074  1.055137  1.055812  1.153381  1.169508  1.143472  1.206365
# 131      1.028649  1.054093  1.111513  1.111078  1.177803  1.215104  1.167226
# 141      0.986751  0.989727  1.121225  1.138198  1.158439  1.279644  1.137475
# 151      1.070181  1.145287  1.146389  1.155823  1.186214  1.201086  1.098366
# 161      1.085227  1.047338  1.176331  1.181724  1.185988  1.253688  1.220259
# 171      1.145601  1.162672  1.148551  1.232563  1.156652  1.214587  1.286177
# 181      1.070000  1.166949  1.147370  1.188781  1.217866  1.250501  1.318309
# 191      1.064616  1.168022  1.150307  1.159093  1.141286  1.272219  1.252884
# 201      1.050494  1.134384  1.243364  1.203972  1.205814  1.412225  1.076103
# 211      1.155754  1.173210  1.152359  1.190791  1.321807  1.193437  1.064226
# 221      1.172396  1.161882  1.161935  1.132154  1.282824  1.076221  1.059851
# 231      1.148577  1.235115  1.271329  1.221068  1.261922  1.113373  1.048100
# 241      1.126312  1.144507  1.126928  1.294582  1.170348  1.081978  1.016043
# 251      1.126093  1.165536  1.152904  1.236438  1.059616  1.128044  1.099506
# 261      1.212497  1.139335  1.287604  1.294305  1.104795  1.092624  1.052091
# 271      1.224477  1.273837  1.300831  1.201775  1.143162  1.096639  1.136176
# 281      1.240193  1.173087  1.243045  1.069470  1.098477  1.107687  1.061438
# 291      1.210827  1.213574  1.313675  1.128889  1.108697  1.043309  1.037247
#
# Windows       121       131       141  ...       201       211       221  \
# Freq                                   ...
# 51       0.919219  1.007673  0.990563  ...  1.092831  1.060359  1.138387
# 61       0.978908  0.993326  1.040826  ...  1.131274  1.141559  1.137977
# 71       1.066681  1.071023  1.069469  ...  1.236469  1.090078  1.115203
# 81       1.063753  1.182637  1.145699  ...  1.235161  1.145360  1.183735
# 91       1.056253  1.142077  1.164269  ...  1.272632  1.286787  1.286978
# 101      1.121585  1.188381  1.218342  ...  1.258031  1.157832  1.031798
# 111      1.135466  1.160401  1.211146  ...  1.049558  1.014296  1.085832
# 121      1.160596  1.183597  1.225958  ...  1.089102  1.056188  1.069110
# 131      1.178808  1.204473  1.262861  ...  1.058696  1.092601  1.041818
# 141      1.159789  1.224241  1.285155  ...  1.068214  1.098393  1.016701
# 151      1.234063  1.347173  1.178525  ...  1.105738  1.054562  1.093520
# 161      1.243615  1.205193  1.069847  ...  1.074116  1.071700  1.087170
# 171      1.324477  1.074764  1.119040  ...  1.087239  1.141634  1.046331
# 181      1.134121  1.096492  1.068363  ...  1.117498  1.078734  1.011241
# 191      1.100868  1.108236  1.089765  ...  1.002878  1.068518  1.042408
# 201      1.102922  1.128747  1.161220  ...  1.000366  1.006279  1.096513
# 211      1.080705  1.090599  1.136004  ...  1.026407  1.097434  1.133926
# 221      1.061508  1.068693  1.031594  ...  1.087538  1.110073  1.079718
# 231      1.097821  1.078252  1.061495  ...  1.105563  1.107574  1.120259
# 241      1.044594  1.005289  1.057712  ...  1.132687  1.138472  1.164369
# 251      1.065446  1.096562  1.077304  ...  1.090904  1.128703  1.106069
# 261      1.028010  1.077427  1.060391  ...  1.141876  1.127236  1.049894
# 271      1.073800  1.109921  1.063613  ...  1.120773  1.053755  1.125566
# 281      1.077742  1.091394  1.078684  ...  1.085132  1.120842  1.037879
# 291      1.062307  1.031838  1.019585  ...  1.084465  1.012810  1.004945
#
# Windows       231       241       251       261       271       281       291
# Freq
# 51       1.149424  1.107376  1.136098  1.150133  1.146976  1.180211  1.080510
# 61       1.226206  1.166734  1.148716  1.163992  1.075404  1.151432  1.210260
# 71       1.163364  1.198240  1.220814  1.207513  1.287173  1.279803  1.198805
# 81       1.275997  1.280948  1.207929  1.197380  1.093180  1.084607  1.093715
# 91       1.176039  1.074496  1.059430  1.128938  1.072637  1.042283  1.064400
# 101      1.061325  1.089094  1.098221  1.039237  1.109282  1.072385  1.105348
# 111      0.993980  1.053268  1.139878  1.078216  1.117446  1.019094  1.112717
# 121      1.133003  1.069293  1.066805  1.042222  1.096162  1.073244  1.163045
# 131      1.083368  1.045092  1.150146  1.079286  1.123159  1.070694  1.105920
# 141      1.035056  1.099223  1.129863  1.057199  1.063239  1.034513  1.047201
# 151      1.078241  1.117824  1.064678  1.046887  1.064838  1.105428  1.065982
# 161      1.049056  1.040379  1.031554  1.031768  1.100589  1.125968  1.129313
# 171      1.094114  1.006355  1.020320  1.122844  1.108185  1.112316  1.092762
# 181      1.004409  1.066665  1.073327  1.151208  1.050932  1.052496  1.113707
# 191      1.039506  1.085138  1.086099  1.082293  1.147164  1.146644  1.117457
# 201      1.126662  1.075856  1.088075  1.061083  1.158423  1.073214  1.110083
# 211      1.061541  1.125228  1.148519  1.101518  1.069851  1.173181  1.043004
# 221      1.065908  1.152725  1.048741  1.072638  1.105883  1.014982  1.024595
# 231      1.131623  1.124387  1.103445  1.097290  0.989344  1.052183  1.105489
# 241      1.099937  1.128686  1.075202  1.031134  1.003085  1.098171  1.106892
# 251      1.104767  1.057036  1.006557  1.000406  1.073389  1.085839  1.024094
# 261      1.073279  1.006735  1.006727  1.084365  1.048240  1.049121  1.060422
# 271      1.029685  1.030267  1.095300  1.113451  1.055254  1.053347  1.047558
# 281      1.030364  1.065271  1.095748  1.070424  1.092859  1.049144  1.016888
# 291      1.075726  1.109104  1.024589  1.077344  1.031718  1.004028  1.029904
#
# [25 rows x 25 columns]

# %% [markdown]
# __Plot heatmap of the perfoemance with all possible hyperparameter combination of `window` and `frequency`__

# %%
plt.figure(figsize=(12,8))
sns.set_theme(font_scale=1.5)
sns.heatmap(matrix, cmap = "RdYlGn", robust = True, cbar_kws = {"label": "Multiple"})
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Updating the ConBacktester Class (Two Parameter Optimization)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")
from itertools import product
import seaborn as sns

# %%
# Version 4.1 (Smoothing and Optimization)

class ConBacktester():
    ''' Class for the vectorized backtesting of simple contrarian trading strategies.
    
    Attributes
    ============
    filepath: str
        local filepath of the dataset (csv-file)
    symbol: str
        ticker symbol (instrument) to be backtested
    start: str
        start date for data import
    end: str
        end date for data import
    tc: float
        proportional trading costs per trade
    
    
    Methods
    =======
    get_data:
        imports the data.
        
    test_strategy:
        prepares the data and backtests the trading strategy incl. reporting (wrapper).
        
    prepare_data:
        prepares the data for backtesting.
    
    run_backtest:
        runs the strategy backtest.
        
    upsample:
        upsamples/copies trading positions back to higher frequency.
        
    plot_results:
        plots the cumulative performance of the trading strategy compared to buy-and-hold.
        
    optimize_strategy:
        backtests strategy for different parameter values incl. optimization and reporting (wrapper).
    
    find_best_strategy:
        finds the optimal strategy (global maximum) given the parameter ranges.
        
    visualize_many:
        plots parameter values vs. performance. 
        
    print_performance:
        calculates and prints various performance metrics.
        
    '''    
    
    def __init__(self, filepath, symbol, start, end, tc):
        
        self.filepath = filepath 
        self.symbol = symbol
        self.start = start
        self.end = end
        self.tc = tc
        self.results = None
        self.get_data() # load the data
        self.tp_year = (self.data.price.count() / ((self.data.index[-1] - self.data.index[0]).days / 365.25)) # how many trades per year ? 100? 300? 1200?
        
    def __repr__(self):
        return "ConBacktester(symbol = {}, start = {}, end = {})".format(self.symbol, self.start, self.end)


    # Get the data    
    def get_data(self):
        ''' Imports the data.
        '''
        raw = pd.read_csv(self.filepath, parse_dates = ["time"], index_col = "time") # 1. read the csv file.
        raw = raw[self.symbol].to_frame().fillna(method = "ffill")                   # 2. extract the instrument data, fill NaN. 
        raw = raw.loc[self.start:self.end].copy()                                    # 3. extract the dates.
        raw.rename(columns={self.symbol: "price"}, inplace=True)                     # 4. rename the column to 'price'.
        raw["returns"] = np.log(raw.price / raw.price.shift(1))                      # 5. compute the log return. 
        self.data = raw
        
    # Run the strategy    
    def test_strategy(self, freq = 60, window = 1): 
        '''
        Prepares the data and backtests the trading strategy incl. reporting (Wrapper).
         
        Parameters
        ============
        freq: int
            data frequency/granularity to work with (in minutes)
        
        window: int
            time window (number of bars) to be considered for the strategy.
        '''
        self.freq = "{}min".format(freq) # 1. create frequency format (for resampling in pandas) 
        self.window = window             # 2. set the windows size
                                
        self.prepare_data(freq, window)  # 3. prepare the data (based on frequency and window)
        self.upsample()                  # 4. upsample the frequency (copies trading positions back to higher frequency)
        self.run_backtest()              # 5. run the strategy
         
                                         # 6. compute cumelatuve returns
        data = self.results.copy()
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data
        
        self.print_performance()
    
    # Prepare the data
    def prepare_data(self, freq, window): 
        ''' Prepares the Data for Backtesting.
        '''
        data = self.data.price.to_frame().copy()                         # 1. make a copy
        freq = "{}min".format(freq)                                      # 2. create frequency format
        resamp = data.resample(freq).last().dropna().iloc[:-1]           # 3. resample the frequency data, take the last bar from each freq
        resamp["returns"] = np.log(resamp / resamp.shift(1))             # 4. compute log returns
        resamp["roll_return"] = resamp["returns"].rolling(window).mean() # 5. compute the rolling returns
        resamp["position"] = -np.sign(resamp["roll_return"])             # 6. define the positions (based on the strategy)
        resamp.dropna(inplace = True)                                    # 7. drop NaN
        self.results = resamp                                            # 8. store the results
        return resamp 
    
    # Run the back test
    def run_backtest(self):
        ''' Runs the strategy backtest.
        '''
        
        data = self.results.copy()                                     # 1. make a copy
        data["strategy"] = data["position"].shift(1) * data["returns"] # 2. compute the returns
        data["trades"] = data.position.diff().fillna(0).abs()          # 3. determine the number of trades in each bar
        data.strategy = data.strategy - data.trades * self.tc          # 4. subtract transaction/trading costs from pre-cost return
        
        self.results = data

    # Upsample the data   
    def upsample(self):
        '''  Upsamples/copies trading positions back to higher frequency.
        '''
        
        data = self.data.copy()                          # 1. make a copy of the data
        resamp = self.results.copy()                     # 2. Make a copy of the results
        data["position"] = resamp.position.shift()       # 3. shift the position of resamp, and store them 
        data = data.loc[resamp.index[0]:].copy()         # 4. set the data to start from the date if the resamp data frame
        data.position = data.position.shift(-1).ffill()  # 5. shift the position one step back 
        data.dropna(inplace=True)
        self.results = data
    
    def plot_results(self):
        '''  Plots the cumulative performance of the trading strategy compared to buy-and-hold.
        '''
        if self.results is None:
            print("Run test_strategy() first.")
        else:
            title = "{} | Freq = {} | Window = {} | TC = {}".format(self.symbol, self.freq, self.window, self.tc)
            self.results[["creturns", "cstrategy"]].plot(title=title, figsize=(12, 8))
            
    def optimize_strategy(self, freq_range, window_range, metric = "Multiple"): # added: freq_range
        '''
        Backtests strategy for different parameter values incl. Optimization and Reporting (Wrapper).
         
        Parameters
        ============
        freq_range: tuple
            tuples of the form (start, end, step size).
        
        window_range: tuple
            tuples of the form (start, end, step size).
        
        metric: str
            performance metric to be optimized (can be: "Multiple", "Sharpe", "Sortino", "Calmar", "Kelly")
        '''
        
        self.metric = metric
        
        if metric == "Multiple":
            performance_function = self.calculate_multiple
        elif metric == "Sharpe":
            performance_function = self.calculate_sharpe
        elif metric == "Sortino":
            performance_function = self.calculate_sortino
        elif metric == "Calmar": 
            performance_function = self.calculate_calmar
        elif metric == "Kelly": 
            performance_function = self.calculate_kelly_criterion
        
        freqs = range(*freq_range)  # NEW!!!
        windows = range(*window_range)
        
        combinations = list(product(freqs, windows)) # NEW!!!
        
        performance = []
        for comb in combinations: # ADJ!!!
            self.prepare_data(comb[0], comb[1])
            self.upsample()
            self.run_backtest()
            performance.append(performance_function(self.results.strategy))
    
        self.results_overview =  pd.DataFrame(data = np.array(combinations), columns = ["Freq", "Windows"])
        self.results_overview["Performance"] = performance
        self.find_best_strategy()
        
    def find_best_strategy(self):
        ''' Finds the optimal strategy (global maximum) given the parameter ranges.
        '''
        best = self.results_overview.nlargest(1, "Performance")
        freq = best.Freq.iloc[0] # NEW!!!
        window = best.Windows.iloc[0]
        perf = best.Performance.iloc[0]
        print("Frequency: {} | Windows: {} | {}: {}".format(freq, window, self.metric, round(perf, 6))) # added: freq 
        self.test_strategy(freq, window) # added: freq
        
    def visualize_many(self):
        ''' Plots parameter values vs. Performance.
        '''

        if self.results_overview is None:
            print("Run optimize_strategy() first.")
        else: # NEW!!!
            matrix = self.results_overview.pivot(index = "Freq", columns = "Windows", values = "Performance")
            
            plt.figure(figsize=(12,8))
            sns.set_theme(font_scale=1.5)
            sns.heatmap(matrix, cmap = "RdYlGn", robust = True, cbar_kws = {"label": "{}".format(self.metric)})
            plt.show()
            
    ############################## Performance ######################################
    
    def print_performance(self):
        ''' Calculates and prints various Performance Metrics.
        '''
        
        data = self.results.copy()
        strategy_multiple = round(self.calculate_multiple(data.strategy), 6)
        bh_multiple =       round(self.calculate_multiple(data.returns), 6)
        outperf =           round(strategy_multiple - bh_multiple, 6)
        cagr =              round(self.calculate_cagr(data.strategy), 6)
        ann_mean =          round(self.calculate_annualized_mean(data.strategy), 6)
        ann_std =           round(self.calculate_annualized_std(data.strategy), 6)
        sharpe =            round(self.calculate_sharpe(data.strategy), 6)
        sortino =           round(self.calculate_sortino(data.strategy), 6)
        max_drawdown =      round(self.calculate_max_drawdown(data.strategy), 6)
        calmar =            round(self.calculate_calmar(data.strategy), 6)
        max_dd_duration =   round(self.calculate_max_dd_duration(data.strategy), 6)
        kelly_criterion =   round(self.calculate_kelly_criterion(data.strategy), 6)
        
        print(100 * "=")
        print("SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = {} | Freq: {} | WINDOW = {}".format(self.symbol, self.freq, self.window))
        print(100 * "-")
        #print("\n")
        print("PERFORMANCE MEASURES:")
        print("\n")
        print("Multiple (Strategy):         {}".format(strategy_multiple))
        print("Multiple (Buy-and-Hold):     {}".format(bh_multiple))
        print(38 * "-")
        print("Out-/Underperformance:       {}".format(outperf))
        print("\n")
        print("CAGR:                        {}".format(cagr))
        print("Annualized Mean:             {}".format(ann_mean))
        print("Annualized Std:              {}".format(ann_std))
        print("Sharpe Ratio:                {}".format(sharpe))
        print("Sortino Ratio:               {}".format(sortino))
        print("Maximum Drawdown:            {}".format(max_drawdown))
        print("Calmar Ratio:                {}".format(calmar))
        print("Max Drawdown Duration:       {} Days".format(max_dd_duration))
        print("Kelly Criterion:             {}".format(kelly_criterion))
        
        print(100 * "=")
        
    def calculate_multiple(self, series):
        return np.exp(series.sum())
    
    def calculate_cagr(self, series):
        return np.exp(series.sum())**(1/((series.index[-1] - series.index[0]).days / 365.25)) - 1
    
    def calculate_annualized_mean(self, series):
        return series.mean() * self.tp_year
    
    def calculate_annualized_std(self, series):
        return series.std() * np.sqrt(self.tp_year)
    
    def calculate_sharpe(self, series):
        if series.std() == 0:
            return np.nan
        else:
            return series.mean() / series.std() * np.sqrt(self.tp_year)
    
    def calculate_sortino(self, series):
        excess_returns = (series - 0)
        downside_deviation = np.sqrt(np.mean(np.where(excess_returns < 0, excess_returns, 0)**2))
        if downside_deviation == 0:
            return np.nan
        else:
            sortino = (series.mean() - 0) / downside_deviation * np.sqrt(self.tp_year)
            return sortino 
    
    def calculate_max_drawdown(self, series):
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax
        max_dd = drawdown.max()
        return max_dd
    
    def calculate_calmar(self, series):
        max_dd = self.calculate_max_drawdown(series)
        if max_dd == 0:
            return np.nan
        else:
            cagr = self.calculate_cagr(series)
            calmar = cagr / max_dd
            return calmar
    
    def calculate_max_dd_duration(self, series):
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax
    
        begin = drawdown[drawdown == 0].index
        end = begin[1:]
        end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
        periods = end - begin
        max_ddd = periods.max()
        return max_ddd.days
    
    def calculate_kelly_criterion(self, series):
        series = np.exp(series) - 1
        if series.var() == 0:
            return np.nan
        else:
            return series.mean() / series.var()
    
    ############################## Performance ######################################

# %%
filepath = "../Data/one_minute.csv"
symbol = "EURUSD"
start = "2018-01-01"
end = "2019-12-31"
ptc = 0.00007 # proportional trading costs (for each position)

# %%
# Create an instance
tester = ConBacktester(filepath = filepath, # data file 
                       symbol = symbol,     # instrument
                       start = start,       # from date
                       end = end,           # to date
                       tc = ptc)            # proportional trading costs for each position
tester
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13272\2238392574.py:72: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")
# ConBacktester(symbol = EURUSD, start = 2018-01-01, end = 2019-12-31)

# %%
# Optimize hyperparameters:

tester.optimize_strategy(
                         # range of date frequqncy. e.g for time series with freq of 1m,
                         #  we'll change the freqency (of bars) to be: 51m, 56m, and so on.. 
                         freq_range = (51, 300, 5),   
                         # define range of windows size
                         window_range = (51, 300, 5), 
                         # what we want to optimal? 
                         # we choose to optimal the 'multiple'    
                         metric = "Multiple")
# Out:
# Frequency: 201 | Windows: 101 | Multiple: 1.462938
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | Freq: 201min | WINDOW = 101
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.462938
# Multiple (Buy-and-Hold):     0.915552
# --------------------------------------
# Out-/Underperformance:       0.547386
#
#
# CAGR:                        0.216181
# Annualized Mean:             0.196144
# Annualized Std:              0.067655
# Sharpe Ratio:                2.899168
# Sortino Ratio:               4.139652
# Maximum Drawdown:            0.064834
# Calmar Ratio:                3.334392
# Max Drawdown Duration:       83 Days
# Kelly Criterion:             43.351821
# ====================================================================================================

# %%
# Plot the result of the optimal strategy 
tester.plot_results()

# %%
# Visualize an heatmap of all the possible combinations of the hyperparameters that we test.
tester.visualize_many()

# %%
# show the top 10 hyperparameters
tester.results_overview.nlargest(10, "Performance")
# Out:
#       Freq  Windows  Performance
# 1510   201      101     1.412225
# 1016   151      131     1.347173
# 1609   211       96     1.346912
# 967    146      136     1.346191
# 577    106      186     1.344446
# 772    126      161     1.336674
# 1411   191      106     1.333248
# 1263   176      116     1.333048
# 1857   236       86     1.330502
# 1213   171      116     1.325144

# %%
# best strategy with freq = 180
tester.optimize_strategy((180, 181, 1), (80, 140, 1), metric = "Multiple")
# Out:
# Frequency: 180 | Windows: 112 | Multiple: 1.320054
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | Freq: 180min | WINDOW = 112
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.320054
# Multiple (Buy-and-Hold):     0.915725
# --------------------------------------
# Out-/Underperformance:       0.404329
#
#
# CAGR:                        0.153551
# Annualized Mean:             0.143171
# Annualized Std:              0.067665
# Sharpe Ratio:                2.115871
# Sortino Ratio:               3.017504
# Maximum Drawdown:            0.065399
# Calmar Ratio:                2.347908
# Max Drawdown Duration:       91 Days
# Kelly Criterion:             31.769389
# ====================================================================================================

# %%
tester.visualize_many()

# %% [markdown]
# __Conclusion__: there doesn´t exist THE "best frequency". It´s all about the __right combination frequency/window__.

# %%
ptc = 0

# %%
tester = ConBacktester(filepath = filepath, symbol = symbol, start = start, end = end, tc = ptc)
tester
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_13272\2238392574.py:72: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw = raw[self.symbol].to_frame().fillna(method = "ffill")
# ConBacktester(symbol = EURUSD, start = 2018-01-01, end = 2019-12-31)

# %%
tester.optimize_strategy((1, 400, 20), (1, 400, 20), metric = "Multiple")
# Out:
# Frequency: 1 | Windows: 1 | Multiple: 3.499104
# ====================================================================================================
# SIMPLE CONTRARIAN STRATEGY | INSTRUMENT = EURUSD | Freq: 1min | WINDOW = 1
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         3.499104
# Multiple (Buy-and-Hold):     0.932915
# --------------------------------------
# Out-/Underperformance:       2.566189
#
#
# CAGR:                        0.874617
# Annualized Mean:             0.628406
# Annualized Std:              0.066349
# Sharpe Ratio:                9.471283
# Sortino Ratio:               13.398433
# Maximum Drawdown:            0.039522
# Calmar Ratio:                22.129769
# Max Drawdown Duration:       41 Days
# Kelly Criterion:             143.252176
# ====================================================================================================

# %%
tester.plot_results()

# %%
tester.visualize_many()

# %% [markdown]
# __Conclusion__:
# - __Trading Costs won´t allow us to work with higher frequencies__ and to exploit short term volatility.
# - Additional __costs are way higher__ than additional benefits.

# %% [markdown]
# ---
